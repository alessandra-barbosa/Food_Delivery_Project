# %% [markdown]
# # Exercíciosb

# %% [markdown]
# Escreva scritps em Python para resolver os seguintes desafios

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# Some o valor 10 a todos os elementos abaixo, guarde os resultados em uma lista e mostre para o usuário ao final do script.
# jkkkk
#
# ```python
# [
#   10, 11, 423, 2034, 134, 11, 3, 23, 34, 758, 9, 10, 14, 2, 412,34, 123,
#   4132, 4, 12, 3412, 34, 12, 34132, 41, 234, 1, 23,4, 12, 3, 41, 2, 41
# ]
# ```

# %%
lista_final = []

lista_valores = [
    10, 11, 423, 2034, 134, 11, 3, 23, 34, 758, 9, 10, 14, 2, 412,34, 123, 
    4132, 4, 12, 3412, 34, 12, 34132, 41, 234, 1, 23,4, 12, 3, 41, 2, 4123 
]

for valor in lista_valores:
  
  lista_final.append(valor + 10)

print(lista_final)
# Out:
# [20, 21, 433, 2044, 144, 21, 13, 33, 44, 768, 19, 20, 24, 12, 422, 44, 133, 4142, 14, 22, 3422, 44, 22, 34142, 51, 244, 11, 33, 14, 22, 13, 51, 12, 4133]

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Percorra todos os elementos da lista e some 10 aos valores entre 0 e 10, multiplique por 20 os valores entre 11 e 50, subtraia 30 dos valores entre 51 e 100 e divida por 2 os valores acima de 100.
#
# ```python
# [
#   10, 11, 423, 2034, 134, 11, 3, 23, 34, 758, 9, 10, 14, 2, 412,34, 123,
#   4132, 4, 12, 3412, 34, 12, 34132, 41, 234, 1, 23,4, 12, 3, 41, 2, 4123
# ]
# ```

# %%
lista_valores = [
    62, 11, 423, 2034, 134, 11, 3, 23, 34, 758, 9, 10, 14, 2, 412,34, 123, 
    4132, 4, 12, 3412, 34, 12, 34132, 41, 234, 1, 23,4, 12, 3, 41, 2, 4123 
]

# some 10 aos valores entre 0 e 10, 
# multiplique por 20 os valores entre 11 e 50, 
# subtraia 30 dos valores entre 51 e 100
# divida por 2 os valores acima de 100

lista_soma = [  ]
lista_multiplicacao = [  ]
lista_divisao = []
lista_subtracao = []

for valor in lista_valores:

  if valor <= 10:
    lista_soma.append( valor + 10 )

  elif valor <= 50:
    lista_multiplicacao.append( valor * 20 )

  elif valor <= 100:
    lista_subtracao.append( valor - 30 )

  else:
    lista_divisao.append( valor / 2 )

print(lista_soma)
print(lista_multiplicacao)
print(lista_subtracao)
print(lista_divisao)
# Out:
# [13, 19, 20, 12, 14, 11, 14, 13, 12]
# [220, 220, 460, 680, 280, 680, 240, 680, 240, 820, 460, 240, 820]
# [32]
# [211.5, 1017.0, 67.0, 379.0, 206.0, 61.5, 2066.0, 1706.0, 17066.0, 117.0, 2061.5]

# %%
nota = 4

if nota < 5:
  print('reprovado')  # 1

if nota < 7:
  print('recuperação') # 2 

else:
  print('Aprovou')  # 3
# Out:
# reprovado
# recuperação

# %% [markdown]
# ## Exercício 3

# %%
dicionario = {
    'nome': 'Pedro', # 1
    'idade': 33, # 2
    'altura': 1.83 # 3
}

dicionario
len(dicionario)
# Out:
# 3

# %%
#indice   0  1  2  3    4    5    6 
lista = [ 1, 2, 3, 4, 1000,  4,  3.14 ]

len(lista)
# Out:
# 1

# %%
numero = 333333333
numero = 33
numero = 3
texto = 'Pedro'
numero_decimal = 3.14


len(texto)
# Out:
# 5

# %%
num = int( float( '3.14' ) )
num
# Out:
# 3

# %%
type(num)
# Out:
# int

# %% [markdown]
# Crie um script em Python que exiba, cinquenta e duas vezes, a seguinte mensagem “Um valor foi removido da lista”. Além disso, esse script deve mostrar, junto com a mensagem, o número de vezes em que a mensagem foi exibida.

# %%
lista = []

# range( inicio, fim, [quantidade] ) | range(fim)
for valor in list(range(51)): # [ 0:51 [
  print(valor)
  print('Um valor foi removido da lista')
  lista.append(valor)

  print()

print('Quantidade de elementos na lista')
len(lista)  # length
# Out:
# 0
# Um valor foi removido da lista
#
# 1
# Um valor foi removido da lista
#
# 2
# Um valor foi removido da lista
#
# 3
# Um valor foi removido da lista
#
# 4
# Um valor foi removido da lista
#
# 5
# Um valor foi removido da lista
#
# 6
# Um valor foi removido da lista
#
# 7
# Um valor foi removido da lista
#
# 8
# Um valor foi removido da lista
#
# 9
# Um valor foi removido da lista
#
# 10
# Um valor foi removido da lista
#
# 11
# Um valor foi removido da lista
#
# 12
# Um valor foi removido da lista
#
# 13
# Um valor foi removido da lista
#
# 14
# Um valor foi removido da lista
#
# 15
# Um valor foi removido da lista
#
# 16
# Um valor foi removido da lista
#
# 17
# Um valor foi removido da lista
#
# 18
# Um valor foi removido da lista
#
# 19
# Um valor foi removido da lista
#
# 20
# Um valor foi removido da lista
#
# 21
# Um valor foi removido da lista
#
# 22
# Um valor foi removido da lista
#
# 23
# Um valor foi removido da lista
#
# 24
# Um valor foi removido da lista
#
# 25
# ...

# %%
valor = 1

# iteracao  1 2
# valor     2

while valor <= 52:
  print(valor)
  print('Um valor removido da lista')
  print()

  valor = valor + 1
# Out:
# 1
# Um valor removido da lista
#
# 2
# Um valor removido da lista
#
# 3
# Um valor removido da lista
#
# 4
# Um valor removido da lista
#
# 5
# Um valor removido da lista
#
# 6
# Um valor removido da lista
#
# 7
# Um valor removido da lista
#
# 8
# Um valor removido da lista
#
# 9
# Um valor removido da lista
#
# 10
# Um valor removido da lista
#
# 11
# Um valor removido da lista
#
# 12
# Um valor removido da lista
#
# 13
# Um valor removido da lista
#
# 14
# Um valor removido da lista
#
# 15
# Um valor removido da lista
#
# 16
# Um valor removido da lista
#
# 17
# Um valor removido da lista
#
# 18
# Um valor removido da lista
#
# 19
# Um valor removido da lista
#
# 20
# Um valor removido da lista
#
# 21
# Um valor removido da lista
#
# 22
# Um valor removido da lista
#
# 23
# Um valor removido da lista
#
# 24
# Um valor removido da lista
#
# 25
# Um valor removido da lista
#
# 26
# Um valor removido da lista
#
# 27
# Um valor removido da lista
#
# 28
# Um valor removido da lista
#
# ...

# %%
pi = 1
euler = 2.718281828459045235360287

# %%
print(pi)
# Out:
# 3.141592653589793

# %%
print('Pedro, o valor do PI é: {0:.2f} -  o numero e: {1:.2f}'.format(pi, euler))
# Out:
# Pedro, o valor do PI é: 3.14 -  o numero e: 2.72

# %%
print(f'Pedro, o valor do PI é: {pi:.3f} -  o numero e: {euler}')
# Out:
# Pedro, o valor do PI é: 3.142 -  o numero e: 2.718281828459045

# %%
num1 = 1
num2 = 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-0d57090bcbfd> in <module>
#       1 num1 = 1
#       2 num2 = 100
# ----> 3 print(f'{num1:.3n}')
#       4 print(f'{num2:.3n}')
#
# ValueError: Precision not allowed in integer format specifier

# %%
for numero in range(1, 1000, 100):
  print(f'{numero}', end=' ')
# Out:
# 1 101 201 301 401 501 601 701 801 901

# %%
# round(valor, qtd_casa)

# indice    0    1      2     3      4
lista1 = [ 0.1,  0.2,  0.4, 0.003, 0.40003 ]
lista2 = [ 0.14, 0.26, 0.8, 0.3,   0.5123 ]
resultados  = []

for indice in range(5):
  resultado = lista1[indice] / lista2[indice]

  resultado = round(resultado, 1)

  resultados.append(resultado)

print(resultados)
# Out:
# [0.7, 0.8, 0.5, 0.0, 0.8]

# %%
for valor in resultados:
  print(f'{valor:.1f}', end="   ")
# Out:
# 0.7   0.8   0.5   0.0   0.8
